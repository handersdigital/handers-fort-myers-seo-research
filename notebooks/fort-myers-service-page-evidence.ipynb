# %% [markdown]
# # Fort Myers service-page evidence worksheet
#
# This notebook turns a local landing-page review into a repeatable evidence check. It is designed for service-area businesses that serve Fort Myers and Southwest Florida without implying an unverified storefront or office.

# %%
checks = {
    "service_area_is_explicit": True,
    "service_is_specific": True,
    "next_step_is_tested": True,
    "local_claims_are_verifiable": True,
    "follow_up_owner_is_named": True,
}
passed = sum(checks.values())
print(f"Evidence checks passed: {passed}/{len(checks)}")
# Out:
# Evidence checks passed: 5/5

# %% [markdown]
# ## How to use the result
#
# A low score is a signal to repair the page and inquiry path before cloning the template across more locations. The page should explain the service, state the coverage boundary accurately, and carry the visitor through contact and follow-up.
#
# [Handers Digital's Fort Myers SEO work](https://handers.digital/seo-fort-myers) connects local visibility, website structure, and inquiry follow-up. The worksheet is maintained by Max Tymoshyn, Marketing Expert at Handers Digital; his editorial work is collected on the [Max Tymoshyn author page](https://handers.digital/author/max-tymoshyn).
